# %%
import pandas as pd

# %%
base2020 = pd.read_csv('bases_para_tratar\\2020.csv')
base2021 = pd.read_csv('bases_para_tratar\\2021.csv')
base2022 = pd.read_csv('bases_para_tratar\\2022.csv')
base2023 = pd.read_csv('bases_para_tratar\\2023.csv')
base2024 = pd.read_csv('bases_para_tratar\\2024.csv')
base2025 = pd.read_csv('bases_para_tratar\\2025.csv')
base2026 = pd.read_csv('bases_para_tratar\\2026.csv')

df = pd.concat(
    [base2020, base2021, base2022, base2023, base2024, base2025, base2026],
    ignore_index=True
)

df.to_csv("BPS_20_26_MarcosBhering.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 base2020 = pd.read_csv('bases_para_tratar\\2020.csv')
#       2 base2021 = pd.read_csv('bases_para_tratar\\2021.csv')
#       3 base2022 = pd.read_csv('bases_para_tratar\\2022.csv')
#       4 base2023 = pd.read_csv('bases_para_tratar\\2023.csv')
#
# ...
